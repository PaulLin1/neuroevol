# %%
import torch
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

# Load digits dataset
digits = load_digits()
X = digits.images.reshape(-1, 64).astype('float32') / 16.0  # normalize to [0, 1]
y = digits.target

# Convert to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

# Split into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

# Create TensorDatasets (already in memory)
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)


# In-memory DataLoaders (no on-the-fly transformation needed)
train_loader = DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=len(train_dataset))

# %%
import torch
import torch.nn.functional as F
import random
from neat.genome import Genome, InnovationTracker
import torch.nn as nn

# Simple fitness function: accuracy on a small validation batch
def evaluate_fitness(genome, data_loader, device, quiet=False):
    genome.eval()
    loss_fn = nn.CrossEntropyLoss(reduction="sum")  # sum to average later
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = genome(X_batch)

            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()

            preds = outputs.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

    avg_loss = total_loss / total if total > 0 else float('inf')
    accuracy = correct / total if total > 0 else 0.0

    # In NEAT, fitness is often defined so higher is better, so negative loss is convenient:
    fitness = -avg_loss

    # Optionally print or log metrics:
    if not quiet:
        print(f"Eval - Accuracy: {accuracy:.4f}, Avg Loss: {avg_loss:.4f}, Fitness: {fitness:.4f}")

    return fitness 

def full_evaluation(genome, data_loader, device):
    genome.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = genome(X_batch)
            preds = outputs.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)
    return correct / total if total > 0 else 0.0

# Simple NEAT evolutionary loop
def neat_evolution_loop(train_loader, val_loader,
                        population_size, generations, device,
                        selection_frac=0, mutation_probs=None,
                        use_crossover=False, quiet=False):
    if mutation_probs is None:
        mutation_probs = {
            'weight_mutate': 0.8,
            'weight_reset': 0.2,
            'add_connection': 0.1,
            'add_node': 0.05
        }

    innovation_tracker = InnovationTracker()

    # Initialize population
    population = [Genome(8*8, 10, device=device, innovation_tracker=innovation_tracker)
                  for _ in range(population_size)]

    best_genome = None
    best_fitness = -float('inf')

    for gen in range(generations):
        print(f"\nGeneration {gen+1}")

        # Evaluate fitness
        fitnesses = []
 
        for i, genome in enumerate(population):
            fitness = evaluate_fitness(genome, train_loader, device, quiet)
            fitnesses.append((fitness, genome))
            # if not quiet:
            #     print(f"  Genome {i}: fitness={fitness:.3f}")
            if fitness > best_fitness:
                best_fitness = fitness
                best_genome = genome

        # Sort and select top
        fitnesses.sort(key=lambda x: x[0], reverse=True)
        num_selected = max(2, int(selection_frac * population_size))
        selected = [g for _, g in fitnesses[:num_selected]]

        if not quiet:
            print(f"  Selected top {num_selected} genomes")

        # Create new population
        new_population = [selected[0]]  # Elitism

        while len(new_population) < population_size:
            if use_crossover:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child = parent1.crossover(parent2)
            else:
                parent = random.choice(selected)
                child = parent.clone()

            # Mutations
            if random.random() < mutation_probs['weight_mutate']:
                child.mutate_weights(perturb_chance=0.9, reset_chance=0.1)
            if random.random() < mutation_probs['add_connection']:
                child.mutate_add_connection()
            if random.random() < mutation_probs['add_node']:
                child.mutate_add_node()

            new_population.append(child)
        
        population = new_population
    
        print(f"Best fitness: {best_fitness:.3f}")

    final_accuracy = full_evaluation(best_genome, val_loader, device)
    return best_genome, final_accuracy

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

best_genome, final_accuracy = neat_evolution_loop(train_loader, val_loader, 100, 10, device, quiet=True)
# print("Best model achieved accuracy:", print(final_accuracy))

import cProfile
cProfile.run("neat_evolution_loop(train_loader, val_loader, 100, 10, device, quiet=True)", sort="time")
# Out:
# Generation 1
# Best fitness: -2.303
#
# Generation 2
# Best fitness: -2.303
#
# Generation 3
# Best fitness: -2.303
#
# Generation 4
# Best fitness: -2.303
#
# Generation 5
# Best fitness: -2.303
#
# Generation 6
# Best fitness: -2.303
#
# Generation 7
# Best fitness: -2.303
#
# Generation 8
# Best fitness: -2.303
#
# Generation 9
# Best fitness: -2.303
#
# Generation 10
# Best fitness: -2.303
#          11085961 function calls (11043735 primitive calls) in 9.873 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   4312080    3.736    0.000    3.776    0.000 dataset.py:207(<genexpr>)
#      2102    0.922    0.000    0.922    0.000 {built-in method torch.stack}
#      1001    0.722    0.001    2.138    0.002 genome.py:68(forward)
#     10010    0.719    0.000    0.719    0.000 {built-in method torch.sigmoid}
#   1437360    0.658    0.000    4.434    0.000 dataset.py:206(__getitem__)
#     10010    0.563    0.000    0.563    0.000 {built-in method torch.matmul}
#      2002    0.533    0.000    6.974    0.003 dataloader.py:787(_next_data)
# 3003/1001    0.287    0.000    1.506    0.002 collate.py:118(collate)
#   1437360    0.155    0.000    0.210    0.000 collate.py:206(<genexpr>)
#      1001    0.141    0.000    6.183    0.006 fetch.py:47(fetch)
#      2002    0.100    0.000    0.254    0.000 sampler.py:326(__iter__)
#     36/35    0.100    0.003    9.019    0.258 selectors.py:558(select)
#   1438000    0.091    0.000    0.154    0.000 sampler.py:167(__iter__)
#      1000    0.080    0.000    0.080    0.000 {built-in method torch._C._nn.cross_entropy_loss}
#      2166    0.080    0.000    0.080    0.000 {built-in method torch.zeros}
#       200    0.067    0.000    0.067    0.000 {method 'unbind' of 'torch._C.TensorBase' objects}
#      1001    0.063    0.000    0.274    0.000 {built-in method builtins.all}
#   1461282    0.058    0.000    0.060    0.000 {built-in method builtins.len}
#      1001    0.051    0.000    0.057    0.000 genome.py:53(build_dense_adjacency_matrix)
#       100    0.047    0.000    0.195    0.002 genome.py:19(__init__)
#    140075    0.047    0.000    0.047    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#       780    0.043    0.000    0.061    0.000 genome.py:96(mutate_weights)
#      2276    0.034    0.000    0.034    0.000 {method 'tolist' of 'torch._C.TensorBase' objects}
#      35/1    0.031    0.001    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#     14264    0.026    0.000    0.048    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#      1001    0.023    0.000    0.023    0.000 {method 'argmax' of 'torch._C.TensorBase' objects}
#     17055    0.022    0.000    0.079    0.000 module.py:1944(__setattr__)
#      7945    0.021    0.000    0.039    0.000 _tensor.py:1241(__contains__)
# 133587/103903    0.021    0.000    0.046    0.000 {built-in method builtins.isinstance}
#      1000    0.021    0.000    9.420    0.009 1990467209.py:8(evaluate_fitness)
#      2000    0.021    0.000    0.021    0.000 {built-in method torch.randperm}
#     64234    0.017    0.000    0.017    0.000 genome.py:11(get_innovation)
#      2002    0.017    0.000    0.017    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#      1781    0.014    0.000    0.014    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#      2090    0.014    0.000    0.016    0.000 module.py:466(__init__)
#       200    0.012    0.000    0.079    0.000 _tensor.py:1175(__iter__)
#      7945    0.010    0.000    0.010    0.000 {method 'any' of 'torch._C.TensorBase' objects}
#      6994    0.010    0.000    0.010    0.000 {method 'clone' of 'torch._C.TensorBase' objects}
#     19168    0.009    0.000    0.009    0.000 module.py:1927(__getattr__)
#      7132    0.009    0.000    0.012    0.000 threading.py:1535(enumerate)
#      2001    0.009    0.000    2.234    0.001 module.py:1755(_call_impl)
#      2002    0.008    0.000    7.053    0.004 dataloader.py:728(__next__)
# 14014/4004    0.008    0.000    0.024    0.000 _pytree.py:1071(tree_iter)
#     14577    0.008    0.000    0.012    0.000 parameter.py:10(__instancecheck__)
#       990    0.007    0.000    0.070    0.000 genome.py:258(clone)
#      2002    0.007    0.000    0.007    0.000 {built-in method torch._ops.profiler.}
#      2002    0.006    0.000    0.046    0.000 profiler.py:776(__exit__)
#     15045    0.006    0.000    0.009    0.000 parameter.py:216(__instancecheck__)
#       780    0.006    0.000    0.006    0.000 {built-in method torch.randn_like}
#       866    0.006    0.000    0.006    0.000 {built-in method torch.tensor}
#       106    0.006    0.000    0.062    0.001 genome.py:107(mutate_add_connection)
#     49924    0.005    0.000    0.005    0.000 threading.py:1198(ident)
#      3648    0.005    0.000    0.012    0.000 module.py:512(register_buffer)
#     48573    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#      2002    0.005    0.000    0.927    0.000 collate.py:243(collate_tensor_fn)
#      1001    0.005    0.000    0.017    0.000 dataloader.py:634(__init__)
#      2001    0.005    0.000    0.005    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#     14014    0.005    0.000    0.006    0.000 _pytree.py:818(_is_namedtuple_instance)
#     10680    0.004    0.000    0.010    0.000 {built-in method builtins.hasattr}
#      1001    0.004    0.000    1.610    0.002 collate.py:337(default_collate)
#      2001    0.004    0.000    0.004    0.000 {built-in method torch.empty}
#       986    0.004    0.000    0.004    0.000 {built-in method torch.randn}
#     12950    0.004    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
#      2001    0.004    0.000    2.238    0.001 module.py:1747(_wrapped_call_impl)
#         1    0.003    0.003    0.953    0.953 1990467209.py:55(neat_evolution_loop)
#     30530    0.003    0.000    0.003    0.000 {method 'keys' of 'dict' objects}
#      1000    0.003    0.000    0.003    0.000 {built-in method torch.cat}
#     14014    0.003    0.000    0.009    0.000 _pytree.py:829(_get_node_type)
#       468    0.003    0.000    0.009    0.000 inspect.py:2393(_signature_from_function)
#      2002    0.003    0.000    0.020    0.000 profiler.py:770(__enter__)
#       780    0.003    0.000    0.003    0.000 {built-in method torch.rand_like}
#      3011    0.003    0.000    0.257    0.000 {built-in method builtins.next}
#      2478    0.003    0.000    0.003    0.000 {built-in method _make_subclass}
#      2002    0.002    0.000    0.002    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#      8008    0.002    0.000    0.008    0.000 _pytree.py:836(_is_leaf)
#      2002    0.002    0.000    0.004    0.000 profiler.py:759(__init__)
#      2478    0.002    0.000    0.005    0.000 module.py:574(register_parameter)
#     29622    0.002    0.000    0.002    0.000 {function _ParameterMeta.__instancecheck__ at 0x10c91f240}
#      2342    0.002    0.000    0.002    0.000 {method 'detach' of 'torch._C.TensorBase' objects}
#      1000    0.002    0.000    0.086    0.000 loss.py:1296(forward)
#      2201    0.002    0.000    0.002    0.000 {built-in method torch._C._get_tracing_state}
#   936/468    0.002    0.000    0.014    0.000 inspect.py:2497(_signature_from_callable)
#      5103    0.002    0.000    0.002    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#     16266    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#      4004    0.002    0.000    0.002    0.000 _pytree.py:575(_tuple_flatten)
#     12950    0.002    0.000    0.007    0.000 <frozen abc>:117(__instancecheck__)
#       105    0.002    0.000    0.002    0.000 socket.py:623(send)
#      2002    0.002    0.000    0.003    0.000 _pytree.py:603(_dict_flatten)
#      4030    0.002    0.000    0.004    0.000 grad_mode.py:184(__init__)
#        64    0.002    0.000    0.020    0.000 genome.py:126(mutate_add_node)
#      1000    0.002    0.000    0.002    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#       234    0.002    0.000    0.030    0.000 genome.py:156(_add_edge)
#      1000    0.002    0.000    0.083    0.000 functional.py:3404(cross_entropy)
#      2071    0.002    0.000    0.002    0.000 typing.py:392(inner)
#      1001    0.002    0.000    0.022    0.000 dataloader.py:766(__init__)
#      1001    0.002    0.000    0.011    0.000 module.py:2836(train)
#      2015    0.002    0.000    0.002    0.000 grad_mode.py:75(__init__)
#      2002    0.002    0.000    0.029    0.000 _pytree.py:1410(tree_any)
#       936    0.002    0.000    0.002    0.000 inspect.py:3025(__init__)
#      1872    0.002    0.000    0.003    0.000 inspect.py:2739(__init__)
#      2090    0.002    0.000    0.002    0.000 {built-in method torch._C._log_api_usage_once}
#      1000    0.001    0.000    0.020    0.000 loss.py:50(__init__)
#      2002    0.001    0.000    0.002    0.000 _ops.py:1037(<lambda>)
#      2002    0.001    0.000    0.031    0.000 _ops.py:1035(_must_dispatch_in_python)
#      2015    0.001    0.000    0.004    0.000 grad_mode.py:84(__exit__)
#      2002    0.001    0.000    0.039    0.000 _ops.py:981(__call__)
#      1000    0.001    0.000    0.028    0.000 loss.py:1283(__init__)
#      2042    0.001    0.000    0.027    0.000 {built-in method builtins.any}
#      4030    0.001    0.000    0.001    0.000 {built-in method torch._C._set_grad_enabled}
#      2015    0.001    0.000    0.003    0.000 grad_mode.py:80(__enter__)
#      1001    0.001    0.000    0.001    0.000 dataloader.py:75(create_fetcher)
#        47    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#      2002    0.001    0.000    0.258    0.000 dataloader.py:722(_next_index)
#      1001    0.001    0.000    0.003    0.000 dataloader.py:98(_get_distributed_settings)
#      1000    0.001    0.000    0.013    0.000 loss.py:41(__init__)
#      7183    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#      2015    0.001    0.000    0.001    0.000 _contextlib.py:154(__new__)
#      3001    0.001    0.000    0.002    0.000 dataset.py:209(__len__)
#      2102    0.001    0.000    0.001    0.000 random.py:242(_randbelow_with_getrandbits)
#      2102    0.001    0.000    0.003    0.000 random.py:341(choice)
#      1001    0.001    0.000    0.001    0.000 distributed_c10d.py:1269(is_initialized)
#       100    0.001    0.000    0.001    0.000 {method 'repeat_interleave' of 'torch._C.TensorBase' objects}
#      6126    0.001    0.000    0.001    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      9864    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      1001    0.001    0.000    0.001    0.000 module.py:2740(named_children)
#      2478    0.001    0.000    0.003    0.000 parameter.py:40(__new__)
#      1024    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#      2478    0.001    0.000    0.001    0.000 module.py:1945(remove_from)
#      6045    0.001    0.000    0.001    0.000 {built-in method torch.is_grad_enabled}
#      2002    0.001    0.000    0.017    0.000 _ops.py:1147(__call__)
# 3206/3205    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#         1    0.001    0.001    0.953    0.953 <string>:1(<module>)
#      3983    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      1001    0.001    0.000    0.002    0.000 module.py:2731(children)
#      1001    0.001    0.000    0.022    0.000 dataloader.py:419(_get_iterator)
#      7945    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_unary}
#       468    0.001    0.000    0.002    0.000 inspect.py:2120(_signature_bound_method)
#       200    0.001    0.000    0.001    0.000 {built-in method torch.arange}
#      2000    0.001    0.000    0.003    0.000 sampler.py:160(num_samples)
#      3015    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x10596ca30}
#      3648    0.001    0.000    0.001    0.000 {method 'discard' of 'set' objects}
#      2108    0.001    0.000    0.001    0.000 enum.py:726(__call__)
#      1001    0.001    0.000    0.012    0.000 module.py:2858(eval)
#       468    0.001    0.000    0.001    0.000 inspect.py:176(get_annotations)
#       468    0.001    0.000    0.001    0.000 inspect.py:754(unwrap)
#      1001    0.000    0.000    0.023    0.000 dataloader.py:480(__iter__)
#       100    0.000    0.000    0.000    0.000 {method 'repeat' of 'torch._C.TensorBase' objects}
#      2002    0.000    0.000    0.000    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#       234    0.000    0.000    0.000    0.000 {method 'reshape' of 'torch._C.TensorBase' objects}
#      2340    0.000    0.000    0.000    0.000 inspect.py:3072(<genexpr>)
#      2970    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#      1001    0.000    0.000    0.000    0.000 distributed_c10d.py:721(WORLD)
#        64    0.000    0.000    0.000    0.000 {built-in method torch.nonzero}
#        10    0.000    0.000    0.002    0.000 session.py:754(send)
#      1001    0.000    0.000    0.001    0.000 __init__.py:14(is_available)
#      2108    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#      3711    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       468    0.000    0.000    0.015    0.000 inspect.py:3077(from_callable)
#      4017    0.000    0.000    0.000    0.000 _jit_internal.py:101(is_scripting)
#      1872    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {built-in method torch.ones}
#        36    0.000    0.000    8.932    0.248 base_events.py:1909(_run_once)
#      1000    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#       468    0.000    0.000    0.001    0.000 inspect.py:3093(replace)
#      1001    0.000    0.000    0.000    0.000 <frozen _collections_abc>:341(__subclasshook__)
#      1024    0.000    0.000    0.001    0.000 <frozen abc>:121(__subclasscheck__)
#        40    0.000    0.000    0.001    0.000 iostream.py:655(write)
#      1000    0.000    0.000    0.000    0.000 _reduction.py:8(get_enum)
#      2102    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#      2002    0.000    0.000    0.000    0.000 worker.py:101(get_worker_info)
#      1001    0.000    0.000    0.000    0.000 dataloader.py:499(_index_sampler)
#       468    0.000    0.000    0.015    0.000 inspect.py:3339(signature)
#      3280    0.000    0.000    0.000    0.000 inspect.py:2792(name)
#      2002    0.000    0.000    0.000    0.000 dataloader.py:495(_auto_collation)
#      1872    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#       936    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#        10    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#      1052    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        64    0.000    0.000    0.000    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
#      2002    0.000    0.000    0.000    0.000 __init__.py:129(annotate)
#        47    0.000    0.000    0.002    0.000 attrsettr.py:43(__getattr__)
#        23    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#        40    0.000    0.000    0.001    0.000 interactiveshell.py:3027(write)
#       498    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#      1001    0.000    0.000    0.000    0.000 fetch.py:9(__init__)
#        11    0.000    0.000    0.006    0.001 ioloop.py:750(_run_callback)
#        40    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#      2350    0.000    0.000    0.000    0.000 inspect.py:2804(kind)
#       234    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#      1001    0.000    0.000    0.000    0.000 distributed_c10d.py:596(default_pg)
#        96    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#      1404    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        23    0.000    0.000    0.005    0.000 zmqstream.py:573(_handle_events)
#       234    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#        70    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#       469    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        12    0.000    0.000    0.001    0.000 socket.py:700(send_multipart)
#        10    0.000    0.000    0.003    0.000 iostream.py:616(_flush)
#      1404    0.000    0.000    0.000    0.000 inspect.py:2796(default)
#        20    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       468    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        21    0.000    0.000    0.001    0.000 iostream.py:259(schedule)
#     37/36    0.000    0.000    0.011    0.000 {method 'run' of '_contextvars.Context' objects}
#     37/36    0.000    0.000    0.012    0.000 events.py:86(_run)
#       940    0.000    0.000    0.000    0.000 inspect.py:3085(parameters)
#      1000    0.000    0.000    0.000    0.000 1990467209.py:92(<lambda>)
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        40    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#        20    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method now}
#        24    0.000    0.000    0.001    0.000 zmqstream.py:653(_rebuild_io_state)
#        10    0.000    0.000    0.001    0.000 session.py:690(serialize)
#        81    0.000    0.000    0.000    0.000 base_events.py:734(time)
#       468    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#        36    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        23    0.000    0.000    0.003    0.000 zmqstream.py:614(_handle_recv)
#        10    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        20    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        40    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#       200    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.001    0.001 history.py:1024(writeout_cache)
#        24    0.000    0.000    0.001    0.000 zmqstream.py:676(_update_handler)
#        47    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        16    0.000    0.000    0.000    0.000 events.py:36(__init__)
#        12    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#        23    0.000    0.000    0.002    0.000 zmqstream.py:546(_run_callback)
#        12    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        23    0.000    0.000    0.000    0.000 typing.py:1221(__instancecheck__)
#        40    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#        10    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#        24    0.000    0.000    0.000    0.000 queue.py:97(empty)
#        10    0.000    0.000    0.000    0.000 session.py:649(msg)
#        23    0.000    0.000    0.002    0.000 iostream.py:157(_handle_event)
#        46    0.000    0.000    0.000    0.000 typing.py:1285(__hash__)
#       531    0.000    0.000    0.000    0.000 typing.py:2182(cast)
#        24    0.000    0.000    0.000    0.000 threading.py:1222(is_alive)
#        11    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#        12    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#        10    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        12    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#        10    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        11    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#        10    0.000    0.000    0.000    0.000 session.py:675(sign)
#        12    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#        12    0.000    0.000    0.002    0.000 iostream.py:276(<lambda>)
#        22    0.000    0.000    0.005    0.000 asyncio.py:206(_handle_events)
#        20    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#        10    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#        40    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        50    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        21    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#        29    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        23    0.000    0.000    0.000    0.000 typing.py:1492(__subclasscheck__)
#        10    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        12    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#      27/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        81    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        40    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#        12    0.000    0.000    0.000    0.000 events.py:111(__init__)
#        40    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        20    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        40    0.000    0.000    0.001    0.000 iostream.py:577(_schedule_flush)
#        10    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#        10    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        82    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.001    0.000 iostream.py:271(send_multipart)
#         1    0.000    0.000    0.003    0.003 1990467209.py:40(full_evaluation)
#        24    0.000    0.000    0.000    0.000 threading.py:1155(_wait_for_tstate_lock)
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        61    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        24    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#        47    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        12    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#        62    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        40    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        11    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#        10    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#        24    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 inspect.py:3129(_bind)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        40    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        20    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#        22    0.000    0.000    0.000    0.000 base_events.py:1894(_add_callback)
#        40    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        14    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#        10    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        10    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        22    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#        40    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#        22    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#        22    0.000    0.000    0.000    0.000 {built-in method time.time}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        10    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        40    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#        12    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         4    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#        47    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#        10    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         1    0.000    0.000    0.000    0.000 inspect.py:3268(bind)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.001    0.001 history.py:92(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#        11    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.001    0.001 decorator.py:232(fun)
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        22    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#        11    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 inspect.py:2945(apply_defaults)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.953    0.953 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        10    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 inspect.py:2892(args)
#         3    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#        10    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        16    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 events.py:155(cancel)
#        24    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 futures.py:398(_call_set_state)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#        10    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#        20    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 concurrent.py:185(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 history.py:1008(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#        10    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 base_events.py:838(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 futures.py:315(_set_result_unless_cancelled)
#        12    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 inspect.py:2915(kwargs)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 sampler.py:116(__iter__)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         3    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 genome.py:7(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2884(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:1904(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 base_events.py:720(is_closed)
