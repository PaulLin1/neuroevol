# %%
import torch
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

# Load digits dataset
digits = load_digits()
X = digits.images.reshape(-1, 64).astype('float32') / 16.0  # normalize to [0, 1]
y = digits.target

# Convert to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

# Split into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

# Create TensorDatasets (already in memory)
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)


# In-memory DataLoaders (no on-the-fly transformation needed)
train_loader = DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=len(train_dataset))

# %%
import torch
import torch.nn.functional as F
import random
from neat.genome import Genome, InnovationTracker
import torch.nn as nn

# Simple fitness function: accuracy on a small validation batch
def evaluate_fitness(genome, data_loader, device, quiet=False):
    genome.eval()
    loss_fn = nn.CrossEntropyLoss(reduction="sum")  # sum to average later
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = genome(X_batch)

            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()

            preds = outputs.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

    avg_loss = total_loss / total if total > 0 else float('inf')
    accuracy = correct / total if total > 0 else 0.0

    # In NEAT, fitness is often defined so higher is better, so negative loss is convenient:
    fitness = -avg_loss

    # Optionally print or log metrics:
    if not quiet:
        print(f"Eval - Accuracy: {accuracy:.4f}, Avg Loss: {avg_loss:.4f}, Fitness: {fitness:.4f}")

    return fitness 

def full_evaluation(genome, data_loader, device):
    genome.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = genome(X_batch)
            preds = outputs.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)
    return correct / total if total > 0 else 0.0

# Simple NEAT evolutionary loop
def neat_evolution_loop(train_loader, val_loader,
                        population_size, generations, device,
                        selection_frac=0, mutation_probs=None,
                        use_crossover=False, quiet=False):
    if mutation_probs is None:
        mutation_probs = {
            'weight_mutate': 0.8,
            'weight_reset': 0.2,
            'add_connection': 0.1,
            'add_node': 0.05
        }

    innovation_tracker = InnovationTracker()

    # Initialize population
    population = [Genome(8*8, 10, device=device, innovation_tracker=innovation_tracker)
                  for _ in range(population_size)]

    best_genome = None
    best_fitness = -float('inf')

    for gen in range(generations):
        print(f"\nGeneration {gen+1}")

        # Evaluate fitness
        fitnesses = []
 
        for i, genome in enumerate(population):
            fitness = evaluate_fitness(genome, train_loader, device, quiet)
            fitnesses.append((fitness, genome))
            # if not quiet:
            #     print(f"  Genome {i}: fitness={fitness:.3f}")
            if fitness > best_fitness:
                best_fitness = fitness
                best_genome = genome

        # Sort and select top
        fitnesses.sort(key=lambda x: x[0], reverse=True)
        num_selected = max(2, int(selection_frac * population_size))
        selected = [g for _, g in fitnesses[:num_selected]]

        if not quiet:
            print(f"  Selected top {num_selected} genomes")

        # Create new population
        new_population = [selected[0]]  # Elitism

        while len(new_population) < population_size:
            if use_crossover:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child = parent1.crossover(parent2)
            else:
                parent = random.choice(selected)
                child = parent.clone()

            # Mutations
            if random.random() < mutation_probs['weight_mutate']:
                child.mutate_weights(perturb_chance=0.9, reset_chance=0.1)
            if random.random() < mutation_probs['add_connection']:
                child.mutate_add_connection()
            if random.random() < mutation_probs['add_node']:
                child.mutate_add_node()

            new_population.append(child)
        
        population = new_population
    
        print(f"Best fitness: {best_fitness:.3f}")

    final_accuracy = full_evaluation(best_genome, val_loader, device)
    return best_genome, final_accuracy

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Simple FFN model
class SimpleFFN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(64, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# Evaluation: negative loss as fitness
def evaluate_fitness(model, data_loader, device, quiet=False):
    model.eval()
    loss_fn = nn.CrossEntropyLoss(reduction="sum")
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()
            preds = outputs.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

    avg_loss = total_loss / total if total > 0 else float('inf')
    accuracy = correct / total if total > 0 else 0.0
    fitness = -avg_loss

    if not quiet:
        print(f"Eval - Accuracy: {accuracy:.4f}, Avg Loss: {avg_loss:.4f}, Fitness: {fitness:.4f}")

    return fitness

# Full evaluation (just accuracy)
def full_evaluation(model, data_loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            preds = model(X_batch).argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)
    return correct / total if total > 0 else 0.0

# Standard training loop using evaluate_fitness at the end
def train_and_evaluate(train_loader, val_loader, device, epochs=1000, quiet=False):
    model = SimpleFFN().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        if not quiet:
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

    # Final evaluation
    evaluate_fitness(model, val_loader, device, quiet=False)
    acc = full_evaluation(model, val_loader, device)
    print(f"Final Validation Accuracy: {acc:.4f}")
    return model

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'


import cProfile
cProfile.run("train_and_evaluate(train_loader, val_loader, device, 1000, quiet=True)", sort="time")

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# best_genome, final_accuracy = neat_evolution_loop(train_loader, val_loader, 100, 10, device, quiet=True)
# print("Best model achieved accuracy:", print(final_accuracy))

import cProfile
cProfile.run("neat_evolution_loop(train_loader, val_loader, 100, 10, device, quiet=True)", sort="time")
# Out:
# Generation 1
# Best fitness: -2.303
#
# Generation 2
# Best fitness: -2.303
#
# Generation 3
# Best fitness: -2.303
#
# Generation 4
# Best fitness: -2.303
#
# Generation 5
# Best fitness: -2.302
#
# Generation 6
# Best fitness: -2.302
#
# Generation 7
# Best fitness: -2.302
#
# Generation 8
# Best fitness: -2.302
#
# Generation 9
# Best fitness: -2.302
#
# Generation 10
# Best fitness: -2.302
#          11074769 function calls (11033025 primitive calls) in 11.634 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   4312080    3.982    0.000    4.030    0.000 dataset.py:207(<genexpr>)
#      1001    1.593    0.002    3.121    0.003 genome.py:68(forward)
#      2102    0.959    0.000    0.959    0.000 {built-in method torch.stack}
#     10010    0.807    0.000    0.807    0.000 {built-in method torch.sigmoid}
#   1437360    0.702    0.000    4.733    0.000 dataset.py:206(__getitem__)
#     10010    0.590    0.000    0.590    0.000 {built-in method torch.matmul}
#      2002    0.562    0.000    7.362    0.004 dataloader.py:787(_next_data)
# 3003/1001    0.338    0.000    1.574    0.002 collate.py:118(collate)
#      1000    0.191    0.000    0.191    0.000 {built-in method torch._C._nn.cross_entropy_loss}
#      33/0    0.165    0.005    0.000          {method 'control' of 'select.kqueue' objects}
#      1001    0.147    0.000    6.527    0.007 fetch.py:47(fetch)
#   1437360    0.126    0.000    0.183    0.000 collate.py:206(<genexpr>)
#      2002    0.107    0.000    0.275    0.000 sampler.py:326(__iter__)
#   1438000    0.098    0.000    0.168    0.000 sampler.py:167(__iter__)
#      33/0    0.075    0.002    0.000          selectors.py:558(select)
#       200    0.074    0.000    0.074    0.000 {method 'unbind' of 'torch._C.TensorBase' objects}
#      2145    0.068    0.000    0.068    0.000 {built-in method torch.zeros}
#      1001    0.067    0.000    0.250    0.000 {built-in method builtins.all}
#      1001    0.062    0.000    0.069    0.000 genome.py:53(build_dense_adjacency_matrix)
#   1461548    0.060    0.000    0.063    0.000 {built-in method builtins.len}
#       100    0.050    0.001    0.212    0.002 genome.py:19(__init__)
#    139341    0.050    0.000    0.050    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#       802    0.048    0.000    0.067    0.000 genome.py:96(mutate_weights)
#      2239    0.036    0.000    0.036    0.000 {method 'tolist' of 'torch._C.TensorBase' objects}
#      2001    0.032    0.000    3.356    0.002 module.py:1755(_call_impl)
#     14264    0.031    0.000    0.057    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#      1000    0.027    0.000   10.993    0.011 512960384.py:19(evaluate_fitness)
#      1001    0.025    0.000    0.025    0.000 {method 'argmax' of 'torch._C.TensorBase' objects}
#      2000    0.025    0.000    0.025    0.000 {built-in method torch.randperm}
#      2002    0.024    0.000    0.024    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#     16813    0.024    0.000    0.082    0.000 module.py:1944(__setattr__)
# 129998/100758    0.023    0.000    0.051    0.000 {built-in method builtins.isinstance}
#      7253    0.020    0.000    0.038    0.000 _tensor.py:1241(__contains__)
#      1803    0.020    0.000    0.020    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#         1    0.019    0.019    1.033    1.033 1990467209.py:55(neat_evolution_loop)
#     64184    0.018    0.000    0.018    0.000 genome.py:11(get_innovation)
#      2090    0.016    0.000    0.018    0.000 module.py:466(__init__)
#       200    0.013    0.000    0.090    0.000 _tensor.py:1175(__iter__)
#      2002    0.012    0.000    7.468    0.004 dataloader.py:728(__next__)
#      7132    0.012    0.000    0.015    0.000 threading.py:1535(enumerate)
#      6973    0.011    0.000    0.011    0.000 {method 'clone' of 'torch._C.TensorBase' objects}
#     18851    0.011    0.000    0.011    0.000 module.py:1927(__getattr__)
#      2002    0.011    0.000    0.011    0.000 {built-in method torch._ops.profiler.}
#      7253    0.010    0.000    0.010    0.000 {method 'any' of 'torch._C.TensorBase' objects}
#     14406    0.009    0.000    0.013    0.000 parameter.py:10(__instancecheck__)
# 14014/4004    0.009    0.000    0.027    0.000 _pytree.py:1071(tree_iter)
#      2002    0.009    0.000    0.058    0.000 profiler.py:776(__exit__)
#       990    0.008    0.000    0.075    0.000 genome.py:258(clone)
#     57056    0.007    0.000    0.007    0.000 threading.py:1198(ident)
#        98    0.007    0.000    0.063    0.001 genome.py:107(mutate_add_connection)
#      2002    0.007    0.000    0.966    0.000 collate.py:243(collate_tensor_fn)
#     14774    0.006    0.000    0.010    0.000 parameter.py:216(__instancecheck__)
#       802    0.006    0.000    0.006    0.000 {built-in method torch.randn_like}
#      2001    0.006    0.000    0.006    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#      1001    0.006    0.000    1.654    0.002 collate.py:337(default_collate)
#      3548    0.006    0.000    0.014    0.000 module.py:512(register_buffer)
#       695    0.006    0.000    0.006    0.000 {built-in method torch.tensor}
#     14014    0.005    0.000    0.006    0.000 _pytree.py:818(_is_namedtuple_instance)
#     47489    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#      1001    0.005    0.000    0.022    0.000 dataloader.py:634(__init__)
#     10407    0.005    0.000    0.013    0.000 {built-in method builtins.hasattr}
#      2001    0.005    0.000    0.005    0.000 {built-in method torch.empty}
#     12258    0.005    0.000    0.007    0.000 {built-in method _abc._abc_instancecheck}
#      2001    0.005    0.000    3.361    0.002 module.py:1747(_wrapped_call_impl)
#      1000    0.004    0.000    0.004    0.000 {built-in method torch.randn}
#      2002    0.004    0.000    0.004    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#      2002    0.004    0.000    0.029    0.000 profiler.py:770(__enter__)
#     30530    0.004    0.000    0.004    0.000 {method 'keys' of 'dict' objects}
#      2201    0.004    0.000    0.004    0.000 {built-in method torch._C._get_tracing_state}
#      3011    0.003    0.000    0.279    0.000 {built-in method builtins.next}
#      1000    0.003    0.000    0.199    0.000 loss.py:1296(forward)
#      2002    0.003    0.000    0.006    0.000 profiler.py:759(__init__)
#     14014    0.003    0.000    0.009    0.000 _pytree.py:829(_get_node_type)
#       779    0.003    0.000    0.003    0.000 {built-in method torch.cat}
#       802    0.003    0.000    0.003    0.000 {built-in method torch.rand_like}
#      8008    0.003    0.000    0.009    0.000 _pytree.py:836(_is_leaf)
#      5103    0.003    0.000    0.003    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#      2407    0.003    0.000    0.003    0.000 {built-in method _make_subclass}
#       368    0.003    0.000    0.008    0.000 inspect.py:2393(_signature_from_function)
#      2250    0.003    0.000    0.003    0.000 {method 'detach' of 'torch._C.TensorBase' objects}
#      2002    0.003    0.000    0.034    0.000 _pytree.py:1410(tree_any)
#      2407    0.003    0.000    0.006    0.000 module.py:574(register_parameter)
#      2068    0.003    0.000    0.003    0.000 typing.py:392(inner)
#      1000    0.002    0.000    0.195    0.000 functional.py:3404(cross_entropy)
#      2002    0.002    0.000    0.003    0.000 _pytree.py:603(_dict_flatten)
#     29180    0.002    0.000    0.002    0.000 {function _ParameterMeta.__instancecheck__ at 0x10c91f240}
#     16266    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#      1000    0.002    0.000    0.002    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#      3974    0.002    0.000    0.004    0.000 grad_mode.py:184(__init__)
#      1001    0.002    0.000    0.014    0.000 module.py:2836(train)
#      1987    0.002    0.000    0.002    0.000 grad_mode.py:75(__init__)
#     12258    0.002    0.000    0.009    0.000 <frozen abc>:117(__instancecheck__)
#      2002    0.002    0.000    0.003    0.000 _ops.py:1037(<lambda>)
#      2090    0.002    0.000    0.002    0.000 {built-in method torch._C._log_api_usage_once}
#      1001    0.002    0.000    0.027    0.000 dataloader.py:766(__init__)
#       104    0.002    0.000    0.003    0.000 socket.py:623(send)
#   736/368    0.002    0.000    0.013    0.000 inspect.py:2497(_signature_from_callable)
#      2002    0.002    0.000    0.036    0.000 _ops.py:1035(_must_dispatch_in_python)
#      2002    0.002    0.000    0.049    0.000 _ops.py:981(__call__)
#      4004    0.002    0.000    0.002    0.000 _pytree.py:575(_tuple_flatten)
#      1987    0.002    0.000    0.004    0.000 grad_mode.py:84(__exit__)
#       184    0.002    0.000    0.027    0.000 genome.py:156(_add_edge)
#      3974    0.002    0.000    0.002    0.000 {built-in method torch._C._set_grad_enabled}
#      1000    0.002    0.000    0.024    0.000 loss.py:50(__init__)
#       736    0.002    0.000    0.002    0.000 inspect.py:3025(__init__)
#      2042    0.002    0.000    0.031    0.000 {built-in method builtins.any}
#      1000    0.002    0.000    0.033    0.000 loss.py:1283(__init__)
#      1987    0.002    0.000    0.003    0.000 grad_mode.py:80(__enter__)
#      1001    0.002    0.000    0.002    0.000 dataloader.py:75(create_fetcher)
#      2002    0.002    0.000    0.280    0.000 dataloader.py:722(_next_index)
#      1472    0.001    0.000    0.003    0.000 inspect.py:2739(__init__)
#        45    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#      1000    0.001    0.000    0.015    0.000 loss.py:41(__init__)
#        43    0.001    0.000    0.015    0.000 genome.py:126(mutate_add_node)
#      1001    0.001    0.000    0.004    0.000 dataloader.py:98(_get_distributed_settings)
#      1024    0.001    0.000    0.002    0.000 {built-in method _abc._abc_subclasscheck}
#      1001    0.001    0.000    0.002    0.000 distributed_c10d.py:1269(is_initialized)
#      3001    0.001    0.000    0.002    0.000 dataset.py:209(__len__)
#      2287    0.001    0.000    0.003    0.000 random.py:341(choice)
#      1987    0.001    0.000    0.002    0.000 _contextlib.py:154(__new__)
#      7183    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#       100    0.001    0.000    0.001    0.000 {method 'repeat_interleave' of 'torch._C.TensorBase' objects}
#      2287    0.001    0.000    0.002    0.000 random.py:242(_randbelow_with_getrandbits)
#      1001    0.001    0.000    0.001    0.000 module.py:2740(named_children)
#      5955    0.001    0.000    0.001    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      2002    0.001    0.000    0.025    0.000 _ops.py:1147(__call__)
#      2407    0.001    0.000    0.004    0.000 parameter.py:40(__new__)
#      1001    0.001    0.000    0.002    0.000 module.py:2731(children)
#      9162    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#         1    0.001    0.001    1.034    1.034 <string>:1(<module>)
#      5961    0.001    0.000    0.001    0.000 {built-in method torch.is_grad_enabled}
#       200    0.001    0.000    0.001    0.000 {built-in method torch.arange}
# 3206/3205    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      2407    0.001    0.000    0.001    0.000 module.py:1945(remove_from)
#      1001    0.001    0.000    0.028    0.000 dataloader.py:419(_get_iterator)
#      3561    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      3548    0.001    0.000    0.001    0.000 {method 'discard' of 'set' objects}
#      2987    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x10596ca30}
#      1001    0.001    0.000    0.015    0.000 module.py:2858(eval)
#      7253    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_unary}
#      2000    0.001    0.000    0.003    0.000 sampler.py:160(num_samples)
#       368    0.001    0.000    0.001    0.000 inspect.py:754(unwrap)
#       100    0.001    0.000    0.001    0.000 {method 'repeat' of 'torch._C.TensorBase' objects}
#      1001    0.001    0.000    0.029    0.000 dataloader.py:480(__iter__)
#      1701    0.001    0.000    0.001    0.000 enum.py:726(__call__)
#       368    0.001    0.000    0.002    0.000 inspect.py:2120(_signature_bound_method)
#      2002    0.001    0.000    0.001    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#       184    0.000    0.000    0.000    0.000 {method 'reshape' of 'torch._C.TensorBase' objects}
#        10    0.000    0.000    0.004    0.000 session.py:754(send)
#       368    0.000    0.000    0.001    0.000 inspect.py:176(get_annotations)
#      1001    0.000    0.000    0.001    0.000 distributed_c10d.py:721(WORLD)
#      1001    0.000    0.000    0.000    0.000 <frozen _collections_abc>:341(__subclasshook__)
#        11    0.000    0.000    0.012    0.001 ioloop.py:750(_run_callback)
#      2970    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#      4192    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       100    0.000    0.000    0.000    0.000 {built-in method torch.ones}
#      1840    0.000    0.000    0.000    0.000 inspect.py:3072(<genexpr>)
#      1000    0.000    0.000    0.000    0.000 _reduction.py:8(get_enum)
#      1000    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#      1001    0.000    0.000    0.001    0.000 __init__.py:14(is_available)
#      33/0    0.000    0.000    0.000          base_events.py:1909(_run_once)
#        40    0.000    0.000    0.001    0.000 iostream.py:655(write)
#       368    0.000    0.000    0.013    0.000 inspect.py:3077(from_callable)
#      2002    0.000    0.000    0.000    0.000 worker.py:101(get_worker_info)
#      1024    0.000    0.000    0.002    0.000 <frozen abc>:121(__subclasscheck__)
#      2287    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#      3989    0.000    0.000    0.000    0.000 _jit_internal.py:101(is_scripting)
#      1701    0.000    0.000    0.000    0.000 enum.py:1129(__new__)
#      1001    0.000    0.000    0.000    0.000 dataloader.py:499(_index_sampler)
#        22    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#       486    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#      1472    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#       368    0.000    0.000    0.001    0.000 inspect.py:3093(replace)
#        45    0.000    0.000    0.002    0.000 attrsettr.py:43(__getattr__)
#      1052    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.002    0.002 history.py:1024(writeout_cache)
#      2002    0.000    0.000    0.000    0.000 dataloader.py:495(_auto_collation)
#       368    0.000    0.000    0.013    0.000 inspect.py:3339(signature)
#        43    0.000    0.000    0.000    0.000 {built-in method torch.nonzero}
#        40    0.000    0.000    0.001    0.000 interactiveshell.py:3027(write)
#      2002    0.000    0.000    0.000    0.000 __init__.py:129(annotate)
#        94    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#      1001    0.000    0.000    0.000    0.000 fetch.py:9(__init__)
#      1472    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#      2580    0.000    0.000    0.000    0.000 inspect.py:2792(name)
#        40    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        11    0.000    0.000    0.001    0.000 socket.py:700(send_multipart)
#        22    0.000    0.000    0.005    0.000 zmqstream.py:573(_handle_events)
#        43    0.000    0.000    0.000    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
#       234    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#       736    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#        68    0.000    0.000    0.000    0.000 enum.py:1562(__and__)
#        10    0.000    0.000    0.004    0.000 iostream.py:616(_flush)
#      1850    0.000    0.000    0.000    0.000 inspect.py:2804(kind)
#      1001    0.000    0.000    0.000    0.000 distributed_c10d.py:596(default_pg)
#        35    0.000    0.000    0.017    0.000 {method 'run' of '_contextvars.Context' objects}
#       234    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#        21    0.000    0.000    0.002    0.000 iostream.py:259(schedule)
#      1104    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       369    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        20    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        35    0.000    0.000    0.018    0.001 events.py:86(_run)
#        40    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#      1000    0.000    0.000    0.000    0.000 1990467209.py:92(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#        99    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        23    0.000    0.000    0.001    0.000 zmqstream.py:653(_rebuild_io_state)
#      1104    0.000    0.000    0.000    0.000 inspect.py:2796(default)
#        20    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#       368    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        10    0.000    0.000    0.001    0.000 session.py:690(serialize)
#        40    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#        22    0.000    0.000    0.003    0.000 zmqstream.py:614(_handle_recv)
#       200    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#        80    0.000    0.000    0.000    0.000 base_events.py:734(time)
#        10    0.000    0.000    0.000    0.000 {built-in method now}
#        20    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.002    0.002 history.py:92(only_when_enabled)
#        22    0.000    0.000    0.002    0.000 zmqstream.py:546(_run_callback)
#        11    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#       740    0.000    0.000    0.000    0.000 inspect.py:3085(parameters)
#        35    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        10    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        22    0.000    0.000    0.002    0.000 iostream.py:157(_handle_event)
#        15    0.000    0.000    0.000    0.000 events.py:36(__init__)
#        23    0.000    0.000    0.001    0.000 zmqstream.py:676(_update_handler)
#        10    0.000    0.000    0.002    0.000 iostream.py:271(send_multipart)
#        12    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#       368    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#        23    0.000    0.000    0.000    0.000 queue.py:97(empty)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        40    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#        23    0.000    0.000    0.000    0.000 typing.py:1221(__instancecheck__)
#        11    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#        24    0.000    0.000    0.000    0.000 threading.py:1222(is_alive)
#        10    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#        12    0.000    0.000    0.000    0.000 base_events.py:767(call_at)
#       530    0.000    0.000    0.000    0.000 typing.py:2182(cast)
#        12    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#        44    0.000    0.000    0.000    0.000 typing.py:1285(__hash__)
#        10    0.000    0.000    0.000    0.000 session.py:649(msg)
#        10    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        12    0.000    0.000    0.000    0.000 base_events.py:743(call_later)
#        10    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#        21    0.000    0.000    0.005    0.000 asyncio.py:206(_handle_events)
#        10    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        10    0.000    0.000    0.000    0.000 session.py:675(sign)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        11    0.000    0.000    0.002    0.000 iostream.py:276(<lambda>)
#        21    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#        40    0.000    0.000    0.001    0.000 iostream.py:577(_schedule_flush)
#        23    0.000    0.000    0.000    0.000 typing.py:1492(__subclasscheck__)
#        20    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#        12    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#        12    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        12    0.000    0.000    0.000    0.000 events.py:111(__init__)
#        10    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#        11    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        20    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        50    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3129(_bind)
#        40    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        40    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        14    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        80    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#      27/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#        11    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        40    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        10    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.003    0.003 512960384.py:46(full_evaluation)
#        81    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        58    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        23    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#        45    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        24    0.000    0.000    0.000    0.000 threading.py:1155(_wait_for_tstate_lock)
#        12    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#        10    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#        57    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         3    0.000    0.000    0.000    0.000 base_events.py:814(_call_soon)
#        20    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        21    0.000    0.000    0.000    0.000 base_events.py:1894(_add_callback)
#        40    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        40    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        40    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#        22    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#         1    0.000    0.000    0.000    0.000 inspect.py:2945(apply_defaults)
#         1    0.000    0.000    0.000    0.000 inspect.py:3268(bind)
#        40    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        10    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         1    0.000    0.000    0.000    0.000 futures.py:398(_call_set_state)
#        23    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#        10    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        40    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        22    0.000    0.000    0.000    0.000 {built-in method time.time}
#        10    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        28    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        21    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#        40    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#        45    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 base_events.py:838(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 history.py:1008(_writeout_input_cache)
#        10    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#        11    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        22    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 inspect.py:2892(args)
#         1    0.000    0.000    0.000    0.000 futures.py:315(_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#        11    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    1.034    1.034 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#        10    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 events.py:155(cancel)
#        10    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:785(call_soon)
#        24    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#        10    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        18    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#         1    0.000    0.000    0.000    0.000 inspect.py:2915(kwargs)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        15    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        10    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#        11    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:684(<lambda>)
#         1    0.000    0.000    0.000    0.000 sampler.py:116(__iter__)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 genome.py:7(__init__)
#         1    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2884(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1904(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:720(is_closed)
